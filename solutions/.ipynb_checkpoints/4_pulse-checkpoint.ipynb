# %% [markdown]
# ---
# # 4. Pulse
#
#
# ## Question 4.1
#
# **When do you want to use Qiskit Pulse?**
#
# **1)**  Performing better calibrations on qubits
#
# **2)**  Measuring coherence time T1 and T2
#
# **3)**  Getting optimized gate errors
#
# **4)**  Accessing higher energy states of transmon qubits
#
# **5)**  All of the above
#
# ### Solution to Q4.1:
#
# The [Calibrating Qubits with Qiskit Pulse](https://qiskit.org/textbook/ch-quantum-hardware/calibrating-qubits-openpulse.html) section from the Qiskit textbook shows how Qiskit Pulse can be used for all of the above.
#
# ### Answer to Q4.1:
#
# **5)** All of the above
#
# ---
# ## Question 4.2
#
# **Which kind of Channel is used for collecting measurement data?**
#
# **1)** `DriveChannel`
#
# **2)** `MeasureChannel`
#
# **3)** `AcquireChannel`
#
# **4)** `ControlChannel`
#
# **5)** None of the above
#
# ### Solution to Q4.2:
#
# From the Qiskit documentation, we can see that [`AcquireChannel`](https://qiskit.org/documentation/stubs/qiskit.pulse.AcquireChannel.html?highlight=acquirechannel#qiskit.pulse.AcquireChannel) is the channel needed to extract the measured data.
#
# ### Answer to Q4.2:
#
# **3)** `AcquireChannel`
#
#
# ---
# ## Question 4.3
#
# **Which kind of Pulse waveforms is used to reduce the chance of leakage to higher energy states of transmon qubits?**
#
# **1)** Constant
#
# **2)** Drag
#
# **3)** Gaussian
#
# **4)** GaussianSquare
#
# **5)** None of the above
#
# ### Solution to Q4.3:
#
# This [Medium article](https://medium.com/qiskit/the-benefits-of-high-resolution-pulses-for-quantum-computers-29f5c510e21) from the Qiskit team describes very well how the DRAG pulse is used to reduce chance of leakage.
#
# ### Answer to Q4.3:
#
# **2)** Drag
#
# ---
# ## Question 4.4
#
# **What is the possible goal of the following Pulse experiment?**
#
# ```
# schedule = pulse.Schedule()
# schedule += Play(drive_pulse, drive_chan)
# schedule += measure << schedule.duration
# schedule_frequencies = [{drive_chan: freq} for freq in frequencies_Hz]
#
# experiment_program = assemble(schedule,
#                             backend=backend,
#                             meas_level=1,
#                             meas_return='avg',
#                             shots=num_shots_per_frequency,
#                             schedule_los=schedule_frequencies)
# ```
#
#
# **1)** Finding the qubit frequency
#
# **2)** Performing a Rabi experiment
#
# **3)** Measuring T1
#
# **4)** Measuring T2
#
# **5)** None of the above
#
# ### Solution to Q4.4:
#
# The [Finding the qubit frequency using a frequency sweep](https://qiskit.org/textbook/ch-quantum-hardware/calibrating-qubits-openpulse.html#frequencysweep) section from the Qiskit textbook explain how this code is used to find the frequency of a qubit.
#
# ### Answer to Q4.4:
#
# **1)** Finding the qubit frequency
#
#
# ---
# ## Question 4.5
#
# **What is the possible goal of the following Pulse experiment?**
#
# ```
# schedules = []
# for drive_amp in drive_amps:
#     pulse = pulse_lib.gaussian(duration=drive_samples, amp=drive_amp,
#                                     sigma=drive_sigma, name=f"Drive amplitude = {drive_amp}")
#     this_schedule = pulse.Schedule(name=f"Drive amplitude = {drive_amp}")
#     this_schedule += Play(pulse, drive_chan)
#     this_schedule += measure << this_schedule.duration
#     schedules.append(this_schedule)
#
# experiment_program = assemble(schedules,
#                             backend=backend,
#                             meas_level=1,
#                             meas_return='avg',
#                             shots=num_shots_per_point,
#                             schedule_los=[{drive_chan: rough_qubit_frequency}]
#                             * num_points)
# ```
#
# **1)** Finding the qubit frequency
#
# **2)** Performing a Rabi experiment
#
# **3)** Measuring T1
#
# **4)** Measuring T2
#
# **5)** None of the above
#
# ### Solution to Q4.5:
#
# The [Calibrating and using a 𝜋 pulse](https://qiskit.org/textbook/ch-quantum-hardware/calibrating-qubits-openpulse.html#calib) section from the Qiskit textbook explains how this code corresponds to a Rabi experiment.
#
#
# ### Answer to Q4.5:
#
# **2)** Performing a Rabi experiment
